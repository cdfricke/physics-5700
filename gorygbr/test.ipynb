# %%
import glob
import pandas as pd
from analysis import analysis
import sys
import numpy as np

def a_err(vg,vg_err):
    eta = 18.13e-6 #N*s/m^2
    g = 9.801 #m/s^2
    rho = 0.86e3 #kg/m^3
    return 1/2 * np.sqrt((9*eta)/(2*g*rho*vg)) * vg_err

# %%
analyzer = analysis()
#analyzer.load("drop_data.csv")

# %%
for data in glob.glob("..\\data\\millikan_data\\drop_data_csv\\*")[38:]:
    analyzer.Analyze(data,2,0.3)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# [-0.00016118546457788522, 0.00016410905900518923, -0.00016413318341471986, 0.00016542961004866225, -0.00016507382722375915, 0.0001630165535661187, -0.0001575783466452807, 0.0001638625179008424]
# [1.1583199167897594e-05, 9.051216382287466e-06, 2.7237920503712506e-05, 2.3504517469834578e-05, 4.272235719856931e-05, 8.822496709088764e-05, 0.00015632209125591076, 8.453852402369652e-05]
# V_g = 0.00016418507420665673 +- 4.0260233647669894e-05 (m/s)
# V_E = 0.00016199270546541126 +- 5.946639203152254e-05 (m/s)
# a = 1.2606298183456032e-06 +- 1.5456109903733225e-07 (m)
# q = 1.418613849701878e-18
# # of Electrons = 8.855267476291374
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# ...

# %%
len(analyzer.Q)
# Out:
# 45

# %%
glob.glob("..\\data\\millikan_data\\drop_data_csv\\*")[38]
# Out:
# '..\\data\\millikan_data\\drop_data_csv\\t9_p3.csv'

# %%
analyzer.files.pop(-2)
# Out:
# '\\t9_p1.csv'

# %%
len(analyzer.files)
# Out:
# 38

# %%
len(analyzer.Q)
# Out:
# 38

# %%
analyzer.export("final_drop_data_please.csv")
