# %%
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import glob
import pandas as pd
from analysis import analysis
import sys

# %%
analyzer = analysis()
analyzer.Analyze("..\\data\\millikan_data\\drop_data_csv\\t11_p1.csv",1)
analyzer.export("test.csv")
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# c:\Users\mesqu\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# [0.07147839839931736, -0.10571366430876607, 0.07067129371239403, -0.10345998552782269, 0.06990196143678651, 0.04054053087503897, 0.0696448342285539, -0.10711853652662999, 0.03333333333333252]
# [0.0034377703044898953, 0.011935902073636038, 0.007593347113460891, 0.037394643227123395, 0.1681737624082118, 1.5916357630669833, 0.02152799638075769, 0.038880842009922374, inf]
# V_g = 0.06268965506319335 +- 1.6006585926377015 (mm/s)
# V_E = 0.10543072878773958 +- 0.055249841409689304 (mm/s)
# a = 7.789663168616834e-07
# q = 4.397027264712691e-19
# # of Electrons = 2.744711151506049

# %%
for path in glob.glob("..\\data\\millikan_data\\drop_data_csv/*"):
        print(path)
        df = pd.read_csv(path)
        #print(df.head)
# Out:
# ..\data\millikan_data\drop_data_csv\t11_p1.csv
# ..\data\millikan_data\drop_data_csv\t11_p2.csv
# ..\data\millikan_data\drop_data_csv\t1_p1.csv
# ..\data\millikan_data\drop_data_csv\t1_p2.csv
# ..\data\millikan_data\drop_data_csv\t1_p3.csv
# ..\data\millikan_data\drop_data_csv\t1_p4.csv
# ..\data\millikan_data\drop_data_csv\t1_p5.csv
# ..\data\millikan_data\drop_data_csv\t2_p1.csv
# ..\data\millikan_data\drop_data_csv\t2_p2.csv
# ..\data\millikan_data\drop_data_csv\t3_p1.csv
# ..\data\millikan_data\drop_data_csv\t4_p1.csv
# ..\data\millikan_data\drop_data_csv\t4_p2.csv
# ..\data\millikan_data\drop_data_csv\t4_p3.csv
# ..\data\millikan_data\drop_data_csv\t4_p4.csv
# ..\data\millikan_data\drop_data_csv\t5_p1.csv
# ..\data\millikan_data\drop_data_csv\t5_p2.csv
# ..\data\millikan_data\drop_data_csv\t6_p1.csv
# ..\data\millikan_data\drop_data_csv\t6_p2.csv
# ..\data\millikan_data\drop_data_csv\t6_p3.csv
# ..\data\millikan_data\drop_data_csv\t6_p4.csv
# ...

# %%
TEST = analysis()
for path in glob.glob("..\\data\\millikan_data\\drop_data_csv/*"):
    TEST.Analyze(path,0,2,0.1)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# c:\Users\mesqu\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 TEST = analysis()
#       2 for path in glob.glob("..\\data\\millikan_data\\drop_data_csv/*"):
# ----> 3     TEST.Analyze(path,0,2,0.1)
#
# File c:\Users\mesqu\Downloads\JSpiegel\physics-5700\gorygbr\analysis.py:49, in analysis.Analyze(self, PATH, verb, win_size, cut)
#      46 LDF.setX(df["t"].to_numpy(),label="Time")
#      47 LDF.setY(df["y"].to_numpy(),label="Y Position")
# ...

# %%
TEST.Q
# Out:
# []
