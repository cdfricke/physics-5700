# %%
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import glob
import pandas as pd
from analysis import analysis
import sys
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\mesqu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 3
#     from analysis import analysis
#
#   File c:\Users\mesqu\Downloads\JSpiegel\physics-5700\gorygbr\analysis.py:43
#     def Analyze(self,PATH:str,verb=1,win_size,cut):
#                                      ^
# SyntaxError: non-default argument follows default argument

# %%
TEST = analysis()
for path in glob.glob("..\\data\\millikan_data\\drop_data_csv/*"):
    TEST.Analyze(path,0,2,0.3)
# Out:
# c:\Users\mesqu\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# c:\Users\mesqu\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# c:\Users\mesqu\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# c:\Users\mesqu\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# ...

# %%
TEST.export("test.csv")

# %%
df = pd.read_csv("test.csv")

# %%
print(df.head(10))
# Out:
#    row             q  electrons             a        VG        VE    VE_err  \
# 0    0  4.397027e-19   2.744711  7.789663e-07  0.062690  0.105431  0.055250
# 1    1  3.309191e-19   2.065662  8.727527e-07  0.078694  0.032523  0.598975
# 2    2  1.921628e-18  11.995184  1.363566e-06  0.192093  0.202423  0.086385
# 3    3  6.059680e-19   3.782572  9.235390e-07  0.088119  0.102988  0.045058
# 4    4  4.854165e-19   3.030065  8.187104e-07  0.069250  0.106127  0.030689
# 5    5  3.124796e-19   1.950559  8.494360e-07  0.074545  0.033735  1.707048
# 6    6  8.122975e-19   5.070521  1.102577e-06  0.125596  0.084775  0.044298
# 7    7  2.397504e-18  14.965692  1.264285e-06  0.165139  0.369246  0.269908
# 8    8  9.501363e-19   5.930938  9.136167e-07  0.086236  0.217067  0.137551
# 9    9  4.553229e-18  28.422154  1.736627e-06  0.311581  0.409149  0.172801
#
#      VG_err     Particle
# 0  1.600659  \t11_p1.csv
# 1  0.008244  \t11_p2.csv
# 2  0.069198  v\t1_p1.csv
# 3  0.060184  v\t1_p2.csv
# ...
